# %%
from pandas_datareader import data as pdr
import plotly.graph_objects as go
import pandas as pd
from datetime import datetime

# %%
df_y = pdr.DataReader('kbank.bk',data_source='yahoo',start='2018-01-01')
df_y.tail()
# Out:
#              High    Low   Open  Close      Volume  Adj Close
# Date
# 2020-05-11  86.25  84.25  84.25  85.00   8942600.0      85.00
# 2020-05-12  85.00  84.00  84.75  84.25  14080100.0      84.25
# 2020-05-13  85.25  84.00  84.25  85.25   7892000.0      85.25
# 2020-05-14  84.75  84.00  84.75  84.25   4952800.0      84.25
# 2020-05-15  84.75  84.00  84.00  83.75   1832400.0      83.75

# %%
df_y.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
df_y.index[0]
# Out:
# Timestamp('2018-01-03 00:00:00')

# %%
df_y.iloc[0]['High']
# Out:
# 237.0

# %%
df_y.iloc[0]['High']+50
# Out:
# 287.0

# %%
df_c = df_y['Close']*2
df_c.head()
# Out:
# Date
# 2018-01-03    474.0
# 2018-01-04    484.0
# 2018-01-05    482.0
# 2018-01-08    482.0
# 2018-01-09    470.0
# Name: Close, dtype: float64

# %%
# df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv')
# fig = go.Figure([go.Scatter(x=df['Date'], y=df['AAPL.High'])])
n = 100
fig = go.Figure()

fig.add_trace(
go.Candlestick(x=df_y.index,
                open=df_y['Open'],
                high=df_y['High'],
                low=df_y['Low'],
                close=df_y['Close'])
)

fig.add_shape(
        # Line Vertical
        dict(
            type="line",
            x0=df_y.index[n],
            y0=df_y.iloc[n]['High']-(df_y.iloc[n]['High']*0.1),
            x1=df_y.index[n],
            y1=df_y.iloc[n]['High']+(df_y.iloc[n]['High']*0.1),
            line=dict(
                color="black",
                width=1.5
            )
))

fig.add_trace(go.Scatter(
    x=[df_y.index[n]],
    y=[df_y.iloc[n]['High']+(df_y.iloc[n]['High']*0.1)+5],
    text=["Trigger"],
    mode="text",
))

# fig.add_trace(
# go.Scatter(x=df['Date'], y=df['AAPL.High']+10)
# )

fig.update_layout(hovermode="x")

fig.show()
# Out:
# <div>
#
#
#             <div id="4eec723c-85ca-4048-9c80-741c6ea1dc01" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4eec723c-85ca-4048-9c80-741c6ea1dc01")) {
#                     Plotly.newPlot(
#                         '4eec723c-85ca-4048-9c80-741c6ea1dc01',
# ...

# %%
# df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv')
# fig = go.Figure([go.Scatter(x=df['Date'], y=df['AAPL.High'])])
fig = go.Figure()

fig.add_trace(
go.Candlestick(x=df_y.index,
                open=df_y['Open'],
                high=df_y['High'],
                low=df_y['Low'],
                close=df_y['Close'])
)

# fig.add_trace(
# go.Scatter(x=df['Date'], y=df['AAPL.High']+10)
# )

fig.update_layout(hovermode="x")

fig.show()
# Out:
# <div>
#
#
#             <div id="fcae2199-7f3d-49f4-84fc-70db369e3d9a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("fcae2199-7f3d-49f4-84fc-70db369e3d9a")) {
#                     Plotly.newPlot(
#                         'fcae2199-7f3d-49f4-84fc-70db369e3d9a',
# ...

# %%
df_y.loc[df_y.index[0],'ema'] = 1

# %%
df_y.iloc[0]
# Out:
# High         2.370000e+02
# Low          2.330000e+02
# Open         2.340000e+02
# Close        2.370000e+02
# Volume       6.816400e+06
# Adj Close    2.170867e+02
# ema          1.000000e+00
# Name: 2018-01-03 00:00:00, dtype: float64

# %%
col = 2
for i in range(0,df_y.shape[0]-3):
    df_y.loc[df_y.index[i+3],'SMA_3'] = round(((df_y.iloc[i,col]+ df_y.iloc[i+1,col] +df_y.iloc[i+2,col])/3),1)
    
df_y.head(20)
# Out:
#              High    Low   Open  Close      Volume   Adj Close  ema  SMA_3
# Date
# 2018-01-03  237.0  233.0  234.0  237.0   6816400.0  217.086746  1.0    NaN
# 2018-01-04  244.0  238.0  239.0  242.0   8123000.0  221.666641  NaN    NaN
# 2018-01-05  244.0  240.0  242.0  241.0   6622100.0  220.750656  NaN    NaN
# 2018-01-08  245.0  241.0  243.0  241.0   8454800.0  220.750656  NaN  238.3
# 2018-01-09  240.0  234.0  240.0  235.0  13325700.0  215.254807  NaN  241.3
# 2018-01-10  236.0  232.0  235.0  233.0   7991200.0  213.422852  NaN  241.7
# 2018-01-11  233.0  230.0  233.0  233.0   9907000.0  213.422852  NaN  239.3
# 2018-01-12  239.0  233.0  233.0  238.0   7724600.0  218.002747  NaN  236.0
# 2018-01-15  240.0  233.0  239.0  234.0   8595500.0  214.338821  NaN  233.7
# 2018-01-16  236.0  233.0  236.0  234.0   4317500.0  214.338821  NaN  235.0
# 2018-01-17  234.0  231.0  233.0  232.0   6954100.0  212.506866  NaN  236.0
# ...

# %%
col = 2
for i in range(0,df_y.shape[0]-3):
    
    
    
#     df_y.loc[df_y.index[i+3],'SMA_3'] = round(((df_y.iloc[i,col]+ df_y.iloc[i+1,col] +df_y.iloc[i+2,col])/3),1)
    
df_y.head(20)
